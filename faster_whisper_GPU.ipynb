# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiian109/OpenCode/blob/main/faster_whisper_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1 - 切换CPU到GPU

# %% [markdown]
# 「runtime」→「Change runtime type」→「T4 GPU」

# %% [markdown]
# # Step 2 - 安裝faster_whisper

# %%
# !pip install faster_whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 109.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Step 3 - 上传文件

# %%
# 音频文件.mp3, .w4a， 视频格式.mp4均可

FILE_NAME = 'ted_speech.mp3'

# %% [markdown]
# # Step 4 - 语音转文字

# %%
# %%time

from faster_whisper import WhisperModel

model = WhisperModel('large-v3', device = 'cuda', compute_type = 'float16')

segments, info = model.transcribe(
    FILE_NAME, #需要转换的文件
    beam_size = 5, #Beam Search的参数默认值
    vad_filter = True, #检测无声部分并跳过处理
    without_timestamps = True, #去掉时间轴加快处理速度
    )

print("Detected language '%s' with probability %f" % (info.language, info.language_probability))

results = ''
for segment in segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))
    results += str(segment.text) + '/n'
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.39k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# vocabulary.json:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Detected language 'ja' with probability 0.935547
# ...

# %% [markdown]
# # Step 5 - 保存文本文件

# %%
with open('OUTPUT.txt', 'w') as f:
  f.write(results)
